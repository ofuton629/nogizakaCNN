# %%
#加工なしデータ×vgg-19モデル×Adam

# %%
import torch
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt
import japanize_matplotlib
from torchviz import make_dot
from torchinfo import summary
from IPython.display import display
from tqdm.notebook import tqdm
import torch.optim as optim
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# %%
device = torch.device("cpu")
print(device)
# Out:
# cpu

# %%
# !git clone https://github.com/makaishi2/pythonlibs.git

from pythonlibs.torch_lib1 import *

print(README)
# Out:
# fatal: destination path 'pythonlibs' already exists and is not an empty directory.
# Common Library for PyTorch
# Author: M. Akaishi

# %%
# !tree 加工なし画像
# Out:
# 加工なし画像
# ├── test
# │   ├── endo
# │   │   ├── endo36.JPG
# │   │   ├── endo37.JPG
# │   │   ├── endo38.JPG
# │   │   ├── endo39.JPG
# │   │   ├── endo40.JPG
# │   │   ├── endo41.JPG
# │   │   ├── endo42.JPG
# │   │   ├── endo43.JPG
# │   │   ├── endo44.JPG
# │   │   ├── endo45.JPG
# │   │   ├── endo46.JPG
# │   │   ├── endo47.JPG
# │   │   ├── endo48.JPG
# │   │   ├── endo49.JPG
# │   │   └── endo50.JPG
# │   ├── kaki
# │   │   ├── kaki36.JPG
# │   │   ├── kaki37.JPG
# │   │   ├── kaki38.JPG
# │   │   ├── kaki39.JPG
# │   │   ├── kaki40.JPG
# │   │   ├── kaki41.JPG
# │   │   ├── kaki42.JPG
# │   │   ├── kaki43.JPG
# │   │   ├── kaki44.JPG
# │   │   ├── kaki45.JPG
# │   │   ├── kaki46.JPG
# │   │   ├── kaki47.JPG
# │   │   ├── kaki48.JPG
# │   │   ├── kaki49.JPG
# │   │   └── kaki50.JPG
# │   ├── kubo
# │   │   ├── kubo36.JPG
# │   │   ├── kubo37.JPG
# │   │   ├── kubo38.JPG
# │   │   ├── kubo39.JPG
# │   │   ├── kubo40.JPG
# │   │   ├── kubo41.JPG
# │   │   ├── kubo42.JPG
# │   │   ├── kubo43.JPG
# │   │   ├── kubo44.JPG
# │   │   ├── kubo45.JPG
# │   │   ├── kubo46.JPG
# │   │   ├── kubo47.JPG
# │   │   ├── kubo48.JPG
# │   │   ├── kubo49.JPG
# │   │   └── kubo50.JPG
# │   ├── nagi
# │   │   ├── nagi36.JPG
# │   │   ├── nagi37.JPG
# │   │   ├── nagi38.JPG
# │   │   ├── nagi39.JPG
# │   │   ├── nagi40.JPG
# │   │   ├── nagi41.JPG
# │   │   ├── nagi42.JPG
# │   │   ├── nagi43.JPG
# │   │   ├── nagi44.JPG
# │   │   ├── nagi45.JPG
# │   │   ├── nagi46.JPG
# │   │   ├── nagi47.JPG
# │   │   ├── nagi48.jpg
# │   │   ├── nagi49.JPG
# │   │   └── nagi50.JPG
# │   └── yama
# │       ├── yama36.jpg
# │       ├── yama37.jpg
# │       ├── yama38.JPG
# │       ├── yama39.JPG
# │       ├── yama40.jpg
# │       ├── yama41.JPG
# │       ├── yama42.JPG
# │       ├── yama43.JPG
# │       ├── yama44.JPG
# │       ├── yama45.jpg
# │       ├── yama46.JPG
# │       ├── yama47.JPG
# │       ├── yama48.JPG
# │       ├── yama49.jpg
# │       └── yama50.JPG
# └── train
#     ├── endo
#     │   ├── endo01.JPG
#     │   ├── endo02.JPG
#     │   ├── endo03.JPG
#     │   ├── endo04.JPG
#     │   ├── endo05.JPG
#     │   ├── endo06.JPG
#     │   ├── endo07.JPG
#     │   ├── endo08.JPG
#     │   ├── endo09.JPG
#     │   ├── endo10.JPG
#     │   ├── endo11.JPG
#     │   ├── endo12.JPG
#     │   ├── endo13.JPG
#     │   ├── endo14.JPG
#     │   ├── endo15.JPG
#     │   ├── endo16.JPG
#     │   ├── endo17.JPG
#     │   ├── endo18.JPG
#     │   ├── endo19.JPG
#     │   ├── endo20.JPG
#     │   ├── endo21.JPG
#     │   ├── endo22.JPG
#     │   ├── endo23.JPG
#     │   ├── endo24.JPG
#     │   ├── endo25.JPG
#     │   ├── endo26.JPG
#     │   ├── endo27.JPG
#     │   ├── endo28.JPG
#     │   ├── endo29.jpg
#     │   ├── endo30.JPG
#     │   ├── endo31.JPG
#     │   ├── endo32.JPG
#     │   ├── endo33.JPG
#     │   ├── endo34.JPG
#     │   └── endo35.jpg
#     ├── kaki
#     │   ├── kaki1.JPG
#     │   ├── kaki10.JPG
#     │   ├── kaki11.JPG
#     │   ├── kaki12.JPG
#     │   ├── kaki13.JPG
#     │   ├── kaki14.JPG
#     │   ├── kaki15.JPG
#     │   ├── kaki16.JPG
#     │   ├── kaki17.JPG
#     │   ├── kaki18.JPG
#     │   ├── kaki19.jpg
#     │   ├── kaki2.JPG
#     │   ├── kaki20.JPG
#     │   ├── kaki21.JPG
#     │   ├── kaki22.JPG
#     │   ├── kaki23.JPG
#     │   ├── kaki24.JPG
#     │   ├── kaki25.JPG
#     │   ├── kaki26.JPG
#     │   ├── kaki27.JPG
#     │   ├── kaki28.JPG
#     │   ├── kaki29.JPG
#     │   ├── kaki3.JPG
#     │   ├── kaki30.JPG
#     │   ├── kaki31.JPG
#     │   ├── kaki32.JPG
#     │   ├── kaki33.JPG
#     │   ├── kaki34.JPG
#     │   ├── kaki35.JPG
#     │   ├── kaki4.JPG
#     │   ├── kaki5.JPG
#     │   ├── kaki6.JPG
#     │   ├── kaki7.JPG
#     │   ├── kaki8.JPG
#     │   └── kaki9.JPG
#     ├── kubo
#     │   ├── kubo1.JPG
#     │   ├── kubo10.JPG
#     │   ├── kubo11.JPG
#     │   ├── kubo12.JPG
#     │   ├── kubo13.JPG
#     │   ├── kubo14.JPG
#     │   ├── kubo15.JPG
#     │   ├── kubo16.JPG
#     │   ├── kubo17.JPG
#     │   ├── kubo18.JPG
#     │   ├── kubo19.JPG
#     │   ├── kubo2.JPG
#     │   ├── kubo20.JPG
#     │   ├── kubo21.JPG
#     │   ├── kubo22.JPG
#     │   ├── kubo23.JPG
#     │   ├── kubo24.JPG
#     │   ├── kubo25.JPG
#     │   ├── kubo26.JPG
#     │   ├── kubo27.JPG
#     │   ├── kubo28.JPG
#     │   ├── kubo29.JPG
#     │   ├── kubo3.JPG
#     │   ├── kubo30.JPG
#     │   ├── kubo31.JPG
#     │   ├── kubo32.JPG
#     │   ├── kubo33.JPG
#     │   ├── kubo34.jpg
#     │   ├── kubo35.JPG
#     │   ├── kubo4.JPG
#     │   ├── kubo5.JPG
#     │   ├── kubo6.JPG
#     │   ├── kubo7.JPG
#     │   ├── kubo8.JPG
#     │   └── kubo9.JPG
#     ├── nagi
#     │   ├── nagi1.JPG
#     │   ├── nagi10.JPG
#     │   ├── nagi11.JPG
#     │   ├── nagi12.JPG
#     │   ├── nagi13.JPG
#     │   ├── nagi14.JPG
#     │   ├── nagi15.JPG
#     │   ├── nagi16.JPG
#     │   ├── nagi17.JPG
#     │   ├── nagi18.JPG
#     │   ├── nagi19.JPG
#     │   ├── nagi2.JPG
#     │   ├── nagi20.JPG
#     │   ├── nagi21.JPG
#     │   ├── nagi22.JPG
#     │   ├── nagi23.JPG
#     │   ├── nagi24.JPG
#     │   ├── nagi25.JPG
#     │   ├── nagi26.JPG
#     │   ├── nagi27.JPG
#     │   ├── nagi28.JPG
#     │   ├── nagi29.JPG
#     │   ├── nagi3.JPG
#     │   ├── nagi30.JPG
#     │   ├── nagi31.JPG
#     │   ├── nagi32.JPG
#     │   ├── nagi33.JPG
#     │   ├── nagi34.JPG
#     │   ├── nagi35.JPG
#     │   ├── nagi4.JPG
#     │   ├── nagi5.JPG
#     │   ├── nagi6.JPG
#     │   ├── nagi7.JPG
#     │   ├── nagi8.JPG
#     │   └── nagi9.JPG
#     └── yama
#         ├── yama01.JPG
#         ├── yama02.JPG
#         ├── yama03.JPG
#         ├── yama04.JPG
#         ├── yama05.JPG
#         ├── yama06.JPG
#         ├── yama07.JPG
#         ├── yama08.JPG
#         ├── yama09.JPG
#         ├── yama10.JPG
#         ├── yama11.jpg
#         ├── yama12.JPG
#         ├── yama13.JPG
#         ├── yama14.JPG
#         ├── yama15.JPG
#         ├── yama16.JPG
#         ├── yama17.JPG
#         ├── yama18.JPG
#         ├── yama19.JPG
#         ├── yama20.JPG
#         ├── yama21.JPG
#         ├── yama22.jpg
#         ├── yama23.JPG
#         ├── yama24.jpg
#         ├── yama25.JPG
#         ├── yama26.JPG
#         ├── yama27.JPG
#         ├── yama28.JPG
#         ├── yama29.JPG
#         ├── yama30.JPG
#         ├── yama31.JPG
#         ├── yama32.JPG
#         ├── yama33.JPG
#         ├── yama34.JPG
#         └── yama35.JPG
#
# 13 directories, 250 files

# %%
test_transform = transforms.Compose([transforms.Resize(224),transforms.CenterCrop(224),
                                     transforms.ToTensor(),transforms.Normalize(0.5, 0.5)])

train_transform = transforms.Compose([transforms.RandomHorizontalFlip(p=0.5),  transforms.Resize(224), transforms.CenterCrop(224),
                                      transforms.ToTensor(), transforms.Normalize(0.5, 0.5),
                                      transforms.RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value=0, inplace=False)])

# %%
data_dir='加工なし画像'

import os
train_dir=os.path.join(data_dir,'train')
test_dir=os.path.join(data_dir,'test')

classes=['endo','kaki','kubo','nagi','yama']

train_data=datasets.ImageFolder(train_dir,transform=train_transform)
train_data2=datasets.ImageFolder(train_dir,transform=test_transform)
test_data=datasets.ImageFolder(test_dir,transform=test_transform)

# %%
print(f' 学習データ:{len(train_data)}件')
print(f' 検証データ:{len(test_data)}件')
# Out:
#  学習データ:175件
#  検証データ:75件

# %%
batch_size=10

train_loader=DataLoader(train_data,batch_size=batch_size,shuffle=True)

train_loader2=DataLoader(train_data2,batch_size=175,shuffle=True)

test_loader=DataLoader(test_data,batch_size=batch_size, shuffle=False)

test_loader2=DataLoader(test_data,batch_size=75,shuffle=True)

# %%
torch_seed()
show_images_labels(train_loader2,classes,None,None)

# %%
torch_seed()

show_images_labels(test_loader2, classes, None, None)

# %%
from torchvision import models
net=models.vgg19_bn(pretrained=True)

for param in net.parameters():
    param.requires_grad=False

torch_seed()

in_features=net.classifier[6].in_features
net.classifier[6]=torch.nn.Linear(in_features, 5)

net.avgpool=torch.nn.Identity()

net=net.to(device)

lr=0.001

criterion=torch.nn.CrossEntropyLoss()

optimizer=optim.Adam(net.classifier[6].parameters())

history = np.zeros((0, 5))
# Out:
# /Users/shige/opt/anaconda3/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/shige/opt/anaconda3/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_BN_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_BN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
num_epochs=30

history=fit(net,optimizer,criterion,num_epochs,train_loader,test_loader,device,history)
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [1/30], loss: 1.66145 acc: 0.24571 val_loss: 1.54279, val_acc: 0.33333
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [2/30], loss: 1.26540 acc: 0.51429 val_loss: 1.43252, val_acc: 0.36000
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [3/30], loss: 1.11423 acc: 0.53143 val_loss: 1.42771, val_acc: 0.48000
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [4/30], loss: 0.98376 acc: 0.62286 val_loss: 1.35172, val_acc: 0.44000
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [5/30], loss: 0.92903 acc: 0.66857 val_loss: 1.34976, val_acc: 0.48000
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [6/30], loss: 0.85729 acc: 0.65714 val_loss: 1.31428, val_acc: 0.46667
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [7/30], loss: 0.74933 acc: 0.73143 val_loss: 1.29303, val_acc: 0.53333
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [8/30], loss: 0.79568 acc: 0.69714 val_loss: 1.33349, val_acc: 0.50667
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [9/30], loss: 0.67029 acc: 0.78286 val_loss: 1.32620, val_acc: 0.52000
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [10/30], loss: 0.74685 acc: 0.68000 val_loss: 1.40410, val_acc: 0.44000
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [11/30], loss: 0.79754 acc: 0.72000 val_loss: 1.48066, val_acc: 0.44000
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [12/30], loss: 0.80574 acc: 0.66857 val_loss: 1.36737, val_acc: 0.45333
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [13/30], loss: 0.57256 acc: 0.80571 val_loss: 1.32459, val_acc: 0.54667
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [14/30], loss: 0.59052 acc: 0.82857 val_loss: 1.32284, val_acc: 0.52000
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [15/30], loss: 0.61588 acc: 0.78286 val_loss: 1.41320, val_acc: 0.54667
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [16/30], loss: 0.67209 acc: 0.74857 val_loss: 1.41500, val_acc: 0.53333
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [17/30], loss: 0.60238 acc: 0.77714 val_loss: 1.36757, val_acc: 0.46667
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [18/30], loss: 0.53359 acc: 0.81714 val_loss: 1.34402, val_acc: 0.56000
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [19/30], loss: 0.49320 acc: 0.84571 val_loss: 1.36472, val_acc: 0.53333
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [20/30], loss: 0.63184 acc: 0.75429 val_loss: 1.39626, val_acc: 0.56000
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [21/30], loss: 0.52245 acc: 0.81714 val_loss: 1.34495, val_acc: 0.54667
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [22/30], loss: 0.55594 acc: 0.81143 val_loss: 1.38568, val_acc: 0.54667
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [23/30], loss: 0.50840 acc: 0.81714 val_loss: 1.37754, val_acc: 0.46667
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [24/30], loss: 0.59280 acc: 0.75429 val_loss: 1.39420, val_acc: 0.52000
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [25/30], loss: 0.56048 acc: 0.81143 val_loss: 1.36992, val_acc: 0.46667
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [26/30], loss: 0.39787 acc: 0.85714 val_loss: 1.36436, val_acc: 0.52000
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [27/30], loss: 0.53385 acc: 0.81714 val_loss: 1.36901, val_acc: 0.52000
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [28/30], loss: 0.40876 acc: 0.84571 val_loss: 1.40377, val_acc: 0.56000
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [29/30], loss: 0.59526 acc: 0.80571 val_loss: 1.44506, val_acc: 0.50667
#   0%|          | 0/18 [00:00<?, ?it/s]
# Epoch [30/30], loss: 0.52613 acc: 0.82286 val_loss: 1.45239, val_acc: 0.54667

# %%
evaluate_history(history)
# Out:
# 初期状態: 損失: 1.54279 精度: 0.33333
# 最終状態: 損失: 1.45239 精度: 0.54667

# %%
torch_seed()

show_images_labels(test_loader2,classes,net,device)
